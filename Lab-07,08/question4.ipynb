# %%
from ortools.sat.python import cp_model

model = cp_model.CpModel()

var_A = model.NewIntVar(0, 3, "A")
var_B = model.NewIntVar(0, 3, "B")
var_C = model.NewIntVar(0, 3, "C")

model.Add(var_A != var_B)
model.Add(var_B != var_C)
model.Add(var_A + var_B <= 4)

solver = cp_model.CpSolver()
status = solver.Solve(model)

if status in (cp_model.FEASIBLE, cp_model.OPTIMAL):
    print(f"A feasible solution has been found:")
    print(f"  Value for A: {solver.Value(var_A)}")
    print(f"  Value for B: {solver.Value(var_B)}")
    print(f"  Value for C: {solver.Value(var_C)}")
else:
    print("No feasible or optimal solution could be found for the given constraints.")
# Out:
# A feasible solution has been found:
#   Value for A: 0
#   Value for B: 1
#   Value for C: 3

# %%
# !pip install ortools
