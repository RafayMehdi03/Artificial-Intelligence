# %%
class BankAccount:
  def __init__(self,balance):
    self.__balance = balance

  def deposit(self,balance):
    self.__balance += balance
    print(balance,"deposited in the account")

  def withdraw(self,amount):
    if(self.__balance - amount < 0):
      print("Insufficient Balance!")
    else:
      self.__balance -= amount
      print(amount,"withdrawn from the account")

  def get_balance(self):
    return self.__balance


a1 = BankAccount(5000)
a2 = BankAccount(2000)
a1.withdraw(4000)
a2.deposit(2000)
print("Account 1 Balance:",a1.get_balance())
print("Account 2 Balance:",a2.balance) #must cause an error since its private
# Out:
# 4000 withdrawn from the account
# 2000 deposited in the account
# Account 1 Balance: 1000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4225081919.py in <cell line: 0>()
#      23 a2.deposit(2000)
#      24 print("Account 1 Balance:",a1.get_balance())
# ---> 25 print("Account 2 Balance:",a2.balance) #must cause an error since its private
#
# AttributeError: 'BankAccount' object has no attribute 'balance'
